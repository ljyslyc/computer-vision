# %%
import numpy as np
from scipy import signal, sparse
import skimage as sk
import skimage.filters as sf
import skimage.io as skio
from skimage.io import imsave, imshow, show
from skimage.color import grey2rgb
import matplotlib.pyplot as plt

from operations import *
from utils import *
from gradFusion import *

from pathlib import Path
PhotoPath = Path("sample_imgs")

# %%
## 苹果橘子融合
imA = readImageNName("sample_imgs/apple.jpeg")[0]
imO = readImageNName("sample_imgs/orange.jpeg")[0]
imAOMask = readImageNName("sample_imgs/mask2.jpg")[0]
result = multiResBlendOp(imA, imO, imAOMask, 5, 10)
plt.imshow(result)
#testImage("app_orange_5_10.jpg", result)
# gaussian
# for i in range(len(lst)):
#     testImage("monalisa_laplacian_pyr_" + str(i) + ".jpg", scaler(lst[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cfa5c0b01b32> in <module>
#       1 ## 苹果橘子融合
# ----> 2 imA = readImageNName("sample_imgs/apple.jpeg")[0]
#       3 imO = readImageNName("sample_imgs/orange.jpeg")[0]
#       4 imAOMask = readImageNName("sample_imgs/mask2.jpg")[0]
#       5 result = multiResBlendOp(imA, imO, imAOMask, 5, 10)
#
# NameError: name 'readImageNName' is not defined

# %%
nnn = np.squeeze(np.dsplit(imMaskB, [1])[0], axis=2)

newImB, newBMask = shiftObjectNMask(targetYX, imB, nnn, imS)

imSwB = np.copy(imS)

newImB[newImB == 1]

imSwB[newBMask == 1] = newImB[newBMask == 1]
testImage("heresy_overlay.jpg", imSwB)
# Out:
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1428: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# File saved to: trash_imgs/20181003020603_heresy_overlay.jpg

# %%
## 1.4.2

targetYX = (0,0)
imB = readImageNName("sample_imgs/soccer_s.jpg")[0]
imS = readImageNName("sample_imgs/volleyball_s.jpg")[0]
# imPawsMaskB = readImageNName("sample_imgs/paws_maskB.jpg")[0]
imBSMask = readImageNName("sample_imgs/volley_mask_22.png")[0]
# result = multiResBlendOp(imB, imS, imBSMask, 20, 10)
# testImage("volley_basket_20_10.jpg", result)
# result3 = multiResBlendOp(imB, imS, imPawsMaskB, 5, 10)
# testImage("volley_soccer_5_10_paws.jpg", result3)

# result4 = gradFusionOp(targetYX, imB, imS, imPawsMask_B, toyProb=False)

# gaussian

# for i in range(len(lst)):
#     testImage("monalisa_laplacian_pyr_" + str(i) + ".jpg", scaler(lst[i]))

# %%
print(imS.shape, imB.shape, imBSMask.shape)
resultA = gradFusionOp(targetYX, imS, imB, imBSMask, toyProb=False)
resultB = multiResBlendOp(imB, imS, imBSMask, 5, 10)

testImage("volleysoc_0,0_volleymask_22.jpg", resultA)
testImage("volleysoc_volleymask_22_5,10.jpg", resultB)

multiResBlendOp2222(imB, imS, imBSMask, 5, 10)
# Out:
# (300, 300, 3) (300, 300, 3) (300, 300, 3)
# Starting LSQR, color channel: 0
# Finished LSQR, color channel: 0
# Starting LSQR, color channel: 1
# Finished LSQR, color channel: 1
# Starting LSQR, color channel: 2
# Finished LSQR, color channel: 2
# File saved to: trash_imgs/20181003025318_volleysoc_0,0_volleymask_22.jpg
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# ...

# %%
targetYX = (111, 0)

imB = readImageNName("sample_imgs/boba.jpg")[0]
imS = readImageNName("sample_imgs/starbucks.jpg")[0]
imMaskB = readImageNName("sample_imgs/boba_mask.jpg")[0]

result4 = gradFusionOp(targetYX, imS, imB, imMaskB, toyProb=False)

testImage("heresy.jpg", result4)
# Out:
# Starting LSQR, color channel: 0
# Finished LSQR, color channel: 0
# Starting LSQR, color channel: 1
# Finished LSQR, color channel: 1
# Starting LSQR, color channel: 2
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Finished LSQR, color channel: 2
# File saved to: trash_imgs/20181003020559_heresy.jpg
# ...

# %%
# laplacianPyrOp_3D(imA, 5, 5)
volleysocc = readImageNName("docs/20181002232605_volley_soccer_5_10_paws.jpg")[0]
volleysocc_lst = laplacianPyrOp_3D(volleysocc, 5, 10)

for i in range(len(volleysocc_lst)):
    testImage("volleysocc_laplacian_pyr_" + str(i) + ".jpg", scaler(volleysocc_lst[i]))
# Out:
# File saved to: trash_imgs/20181002232718_volleysocc_laplacian_pyr_0.jpg
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1428: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# File saved to: trash_imgs/20181002232718_volleysocc_laplacian_pyr_1.jpg
# ...

# %%
def multiResBlendOp2222(im1, im2, mask, levels, sigma):
    assert im1.shape == im2.shape == mask.shape

    L1 = laplacianPyrOp_3D(im1, levels, sigma)
    L2 = laplacianPyrOp_3D(im2, levels, sigma)
    LM = gaussStackOp_3D(mask, levels, sigma)
    LM1 = LM
    LM2 = (1 - LM1)

    L1_post = LM1 * L1
    L2_post = LM2 * L2
    
    for i in range(len(L1_post)):
        testImage("soccer_laplacian_pyr_" + str(i) + ".jpg", scaler(L1_post[i]))
        
    for i in range(len(L2_post)):
        testImage("volley_laplacian_pyr_" + str(i) + ".jpg", scaler(L2_post[i]))
    return

# multiResBlendOp2222(imB, imS, imPawsMaskB, 5, 10)

# %%
targetYX = (300, 400)
imPolar = readImageNName("sample_imgs/polar_bear.jpg")[0]
imDesert = readImageNName("sample_imgs/desert.jpg")[0]
imPolarMask = readImageNName("sample_imgs/polar_bear_mask.png")[0]

# result = gradFusionOp(targetYX, imDesert, imPolar, imPolarMask, toyProb=False)

# %%
testImage("polar_bear_desert_333,400.jpg", result)
# Out:
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1428: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# File saved to: trash_imgs/20181002235856_polar_bear_desert_333,400.jpg

# %%
# nnn = np.squeeze(np.dsplit(imPolarMask, [1])[0], axis=2)
newImB, newBMask = shiftObjectNMask(targetYX, imPolar, imPolarMask, imDesert)

imSwB = np.copy(imDesert)

imSwB[newBMask != 0] = newImB[newBMask != 0]
testImage("whoah.jpg", newBMask)
testImage("polar_bear_desert_overlay.jpg", imSwB)
# Out:
# File saved to: trash_imgs/20181003013150_whoah.jpg
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /Users/reginaongowarsito/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1428: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# File saved to: trash_imgs/20181003013150_polar_bear_desert_overlay.jpg
